# %% [markdown]
# ## PEI Election Data
#
# Using the data from [Elections PEI - Open Data](https://www.electionspei.ca/resources/open-data), and more specifically [Yearly Political Party Contributions - Open Data](https://www.electionspei.ca/yearly-political-party-contributions-open-data), we create some visualizations of the data.

# %%
# Dependencies.
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../resources/election_contributions.csv')
df
# Out:
#       Year                                              Party  \
# 0     2011                Green Party of Prince Edward Island
# 1     2011                Green Party of Prince Edward Island
# 2     2011                Green Party of Prince Edward Island
# 3     2011                Green Party of Prince Edward Island
# 4     2011                         The Island Party of P.E.I.
# ...    ...                                                ...
# 7746  2020  Progressive Conservative Association of Prince...
# 7747  2020  Progressive Conservative Association of Prince...
# 7748  2020  Progressive Conservative Association of Prince...
# 7749  2020  Progressive Conservative Association of Prince...
# 7750  2020  Progressive Conservative Association of Prince...
#
#                   Last_Name    First_Name Business_Name Address  \
# 0                  Lanthier         Peter           NaN     NaN
# 1                  Lanthier        Darcie           NaN     NaN
# 2                    Munves       Barbara           NaN     NaN
# 3     Green Party of Canada           NaN           NaN     NaN
# 4                  Ferguson        George           NaN     NaN
# ...                     ...           ...           ...     ...
# 7746                  Walsh  Margaret Ann           NaN     NaN
# 7747                Wellner       William           NaN     NaN
# 7748               Wheatley          Ross           NaN     NaN
# 7749                Wheeler          Sean           NaN     NaN
# 7750                Wheeler          Tara           NaN     NaN
#
#                  Community Postal_Code Province Country     Amount
# 0                  Mermaid         NaN      NaN     NaN        350
# 1                  Mermaid         NaN      NaN     NaN        400
# 2            Charlottetown         NaN      NaN     NaN        500
# 3     Malpeque Association         NaN      NaN     NaN       5300
# 4             Murray River         NaN      NaN     NaN        400
# ...                    ...         ...      ...     ...        ...
# 7746             Watervale         NaN       PE     NaN  $1,500.00
# 7747         Charlottetown         NaN       PE     NaN  $3,000.00
# 7748             Stratford         NaN       PE     NaN    $310.26
# 7749         Charlottetown         NaN       PE     NaN    $500.00
# 7750         Charlottetown         NaN       PE     NaN    $500.00
#
# [7751 rows x 11 columns]

# %%
# Change column names.
df.columns = ['Year', 'Party', 'Last Name', 'First Name', 'Business Name', 'Address', 'Community', 'Postal Code', 'Province', 'Country', 'Amount']
df.head()
# Out:
#    Year                                Party              Last Name  \
# 0  2011  Green Party of Prince Edward Island               Lanthier
# 1  2011  Green Party of Prince Edward Island               Lanthier
# 2  2011  Green Party of Prince Edward Island                 Munves
# 3  2011  Green Party of Prince Edward Island  Green Party of Canada
# 4  2011           The Island Party of P.E.I.               Ferguson
#
#   First Name Business Name Address             Community Postal Code Province  \
# 0      Peter           NaN     NaN               Mermaid         NaN      NaN
# 1     Darcie           NaN     NaN               Mermaid         NaN      NaN
# 2    Barbara           NaN     NaN         Charlottetown         NaN      NaN
# 3        NaN           NaN     NaN  Malpeque Association         NaN      NaN
# 4     George           NaN     NaN          Murray River         NaN      NaN
#
#   Country Amount
# 0     NaN    350
# 1     NaN    400
# 2     NaN    500
# 3     NaN   5300
# 4     NaN    400

# %%
# Check parties.
df['Party'].unique()
# Out:
# array(['Green Party of Prince Edward Island',
#        'The Island Party of P.E.I.',
#        'New Democratic Party of Prince Edward Island',
#        'Prince Edward Island Liberal Association',
#        'Progressive Conservative Association of Prince Edward Island'],
#       dtype=object)

# %%
# Change names to simpler forms.
df.replace({'Party': {'Green Party of Prince Edward Island': 'Green Party',
                      'The Island Party of P.E.I.': 'Island Party',
                      'New Democratic Party of Prince Edward Island': 'New Democratic Party',
                      'Prince Edward Island Liberal Association': 'Liberal Party',
                      'Progressive Conservative Association of Prince Edward Island': 'Conservative Party'}}, inplace=True)
df['Party'].unique()
# Out:
# array(['Green Party', 'Island Party', 'New Democratic Party',
#        'Liberal Party', 'Conservative Party'], dtype=object)

# %%
# Fill NaN values in Name columns.
df['Last Name'] = df['Last Name'].fillna('')
df['First Name'] = df['First Name'].fillna('')
df['Business Name'] = df['Business Name'].fillna('')
df.head(10)
# Out:
#    Year                 Party              Last Name First Name Business Name  \
# 0  2011           Green Party               Lanthier      Peter
# 1  2011           Green Party               Lanthier     Darcie
# 2  2011           Green Party                 Munves    Barbara
# 3  2011           Green Party  Green Party of Canada
# 4  2011          Island Party               Ferguson     George
# 5  2011          Island Party                 Murphy  Winnifred
# 6  2011          Island Party                   Cann      Billy
# 7  2011          Island Party                Donahue     Joanne
# 8  2011          Island Party                  Smitz       Paul
# 9  2011  New Democratic Party                  Byrne     Joseph
#
#   Address             Community Postal Code Province Country Amount
# 0     NaN               Mermaid         NaN      NaN     NaN    350
# 1     NaN               Mermaid         NaN      NaN     NaN    400
# 2     NaN         Charlottetown         NaN      NaN     NaN    500
# 3     NaN  Malpeque Association         NaN      NaN     NaN   5300
# 4     NaN          Murray River         NaN      NaN     NaN    400
# 5     NaN                Peakes         NaN      NaN     NaN    400
# 6     NaN            Gaspereaux         NaN      NaN     NaN   1500
# 7     NaN              Cornwall         NaN      NaN     NaN   1540
# 8     NaN             Brookvale         NaN      NaN     NaN   1700
# 9     NaN         Charlottetown         NaN      NaN     NaN    265

# %%
# Combine the Name columns into one Entity column, and drop the Names.
df['Entity'] = df[['First Name', 'Last Name', 'Business Name']].agg(' '.join, axis=1)
df.drop(columns=['First Name', 'Last Name', 'Business Name'])
df = df[['Year', 'Party', 'Entity', 'Address', 'Community', 'Postal Code', 'Province', 'Country', 'Amount']]
df.head(10)
# Out:
#    Year                 Party                   Entity Address  \
# 0  2011           Green Party          Peter Lanthier      NaN
# 1  2011           Green Party         Darcie Lanthier      NaN
# 2  2011           Green Party          Barbara Munves      NaN
# 3  2011           Green Party   Green Party of Canada      NaN
# 4  2011          Island Party         George Ferguson      NaN
# 5  2011          Island Party        Winnifred Murphy      NaN
# 6  2011          Island Party              Billy Cann      NaN
# 7  2011          Island Party          Joanne Donahue      NaN
# 8  2011          Island Party              Paul Smitz      NaN
# 9  2011  New Democratic Party            Joseph Byrne      NaN
#
#               Community Postal Code Province Country Amount
# 0               Mermaid         NaN      NaN     NaN    350
# 1               Mermaid         NaN      NaN     NaN    400
# 2         Charlottetown         NaN      NaN     NaN    500
# 3  Malpeque Association         NaN      NaN     NaN   5300
# 4          Murray River         NaN      NaN     NaN    400
# 5                Peakes         NaN      NaN     NaN    400
# 6            Gaspereaux         NaN      NaN     NaN   1500
# 7              Cornwall         NaN      NaN     NaN   1540
# 8             Brookvale         NaN      NaN     NaN   1700
# 9         Charlottetown         NaN      NaN     NaN    265

# %%
# Check the lengths of columns.
print(f"Address has values in {round(df['Address'].count()/len(df)*100)}% of rows.")
print(f"Postal Code has values in {round(df['Postal Code'].count()/len(df)*100)}% of rows.")
print(f"Province has values in {round(df['Province'].count()/len(df)*100)}% of rows.")
print(f"Country has values in {round(df['Country'].count()/len(df)*100)}% of rows.")
# Out:
# Address has values in 5% of rows.
# Postal Code has values in 5% of rows.
# Province has values in 45% of rows.
# Country has values in 5% of rows.

# %%
# Drop the rows that lack data.
df = df.drop(columns=['Address', 'Postal Code', 'Country'])
df.head()
# Out:
#    Year         Party                   Entity             Community Province  \
# 0  2011   Green Party          Peter Lanthier                Mermaid      NaN
# 1  2011   Green Party         Darcie Lanthier                Mermaid      NaN
# 2  2011   Green Party          Barbara Munves          Charlottetown      NaN
# 3  2011   Green Party   Green Party of Canada   Malpeque Association      NaN
# 4  2011  Island Party         George Ferguson           Murray River      NaN
#
#   Amount
# 0    350
# 1    400
# 2    500
# 3   5300
# 4    400

# %%
# Replace currency with float value.
df['Amount'] = df['Amount'].replace('[\$,]', '', regex=True).astype(float)
df
# Out:
#       Year               Party                   Entity             Community  \
# 0     2011         Green Party          Peter Lanthier                Mermaid
# 1     2011         Green Party         Darcie Lanthier                Mermaid
# 2     2011         Green Party          Barbara Munves          Charlottetown
# 3     2011         Green Party   Green Party of Canada   Malpeque Association
# 4     2011        Island Party         George Ferguson           Murray River
# ...    ...                 ...                      ...                   ...
# 7746  2020  Conservative Party      Margaret Ann Walsh              Watervale
# 7747  2020  Conservative Party         William Wellner          Charlottetown
# 7748  2020  Conservative Party           Ross Wheatley              Stratford
# 7749  2020  Conservative Party            Sean Wheeler          Charlottetown
# 7750  2020  Conservative Party            Tara Wheeler          Charlottetown
#
#      Province   Amount
# 0         NaN   350.00
# 1         NaN   400.00
# 2         NaN   500.00
# 3         NaN  5300.00
# 4         NaN   400.00
# ...       ...      ...
# 7746       PE  1500.00
# 7747       PE  3000.00
# 7748       PE   310.26
# 7749       PE   500.00
# 7750       PE   500.00
#
# [7751 rows x 6 columns]

# %%
# Check Province column.
df['Province'].unique()
# Out:
# array([nan, 'PE  ', 'PE', 'PE ', 'ON', 'NS', 'NB', 'QC', 'AB', 'BC', 'NL',
#        'SK', 'PEI'], dtype=object)

# %%
# Strip and Replace various PEI formats.
df['Province'] = df['Province'].str.strip()
df['Province'] = df['Province'].str.replace('PEI', 'PE')
df['Province'].unique()
# Out:
# array([nan, 'PE', 'ON', 'NS', 'NB', 'QC', 'AB', 'BC', 'NL', 'SK'],
#       dtype=object)

# %%
# Begin cleaning Community column.
df['Community'] = df['Community'].str.replace('\s+', ' ', regex=True)
df['Community'] = df['Community'].str.replace('\sRR\s*\d+', ' ', regex=True)
df['Community'] = df['Community'].str.replace("O Leary|OLeary|O'Leary |O�Leary", "O'Leary", regex=True)
df['Community'] = df['Community'].str.strip()

# %%
# Find all Community values with a letter then a space.
#df.loc[df['Community'].str.contains(r'^\w{1}\s{1}\w+', na=False), 'Community']
df.replace({'Community': {'W heatly River': 'Wheatly River',
                          'W indsor Junction, NS': 'Windsor Junction, NS',
                          'M urray River': 'Murray River',
                          'M orell': 'Morell',
                          'W insloe': 'Winsloe',
                          'M ontague': 'Montague',
                          'W ellington': 'Wellington',
                          'M iscouche': 'Miscouche'}}, inplace=True)
# Replace spelling mistakes I noticed during analysis.
df.replace({'Community': {'Charlotteown': 'Charlottetown',
                          'Charolottetown': 'Charlottetown',
                          'Charlottettown': 'Charlottetown',
                          'Charlottetown Pei': 'Charlottetown',
                          "Ch'Town": 'Charlottetown',
                          'Halifax`': 'Halifax',
                          'NorthWiltshire': 'North Wiltshire',
                          'North W Iltshire': 'North Wiltshire',
                          'Canoe Cove`': 'Canoe Cove',
                          'Stewart': 'Mount Stewart',
                          'Mt Stewart': 'Mount Stewart',
                          'Mt. Stewart': 'Mount Stewart',
                          'Startford': 'Stratford',
                          "St. Peter'S Bay": 'St. Peters Bay',
                          }}, inplace=True)

# %%
# Community values that contain the Province, adding Province Data.
df.loc[df['Community'].str.contains(r'[,|, ]\w{2}$', na=False), 'Province'] = df['Community'].str[-2:]
# Changing the Community to not have the Province.
df.loc[df['Community'].str.contains(r'[,|, ]\w{2}$', na=False), 'Community'] = df['Community'].str.extract('^(.+?),')

# %%
# Turn all values in Community to Title Case.
df['Community'] = df['Community'].str.title()

# %%
# Get unique list of communities.
coms = df['Community'].unique().tolist()
coms[:5]
# Out:
# ['Mermaid', 'Charlottetown', 'Malpeque Association', 'Murray River', 'Peakes']

# %%
# Read in the PEI municipality data.
muns = pd.read_csv('../resources/pei_gov_placefinder.csv')['Place'].tolist()
muns[:5]
# Out:
# ['48 Road', 'Abney', 'Abrams Village', 'Afton', 'Afton Road']

# %%
others = []
# Loop through our Communities and see if they are in PEI.
for com in coms:
    if com in muns:
        df.loc[df['Community'].str.lower() == com.lower(), 'Province'] = 'PE'
    else:
        if com not in others:
            others.append(com)

# %%
# Length of communities not in PE.
len(others)
# Out:
# 96

# %%
# View rows again.
df.head(20)
# Out:
#     Year                 Party                       Entity  \
# 0   2011           Green Party              Peter Lanthier
# 1   2011           Green Party             Darcie Lanthier
# 2   2011           Green Party              Barbara Munves
# 3   2011           Green Party       Green Party of Canada
# 4   2011          Island Party             George Ferguson
# 5   2011          Island Party            Winnifred Murphy
# 6   2011          Island Party                  Billy Cann
# 7   2011          Island Party              Joanne Donahue
# 8   2011          Island Party                  Paul Smitz
# 9   2011  New Democratic Party                Joseph Byrne
# 10  2011  New Democratic Party                  Mary Burke
# 11  2011  New Democratic Party                  Fred Horne
# 12  2011  New Democratic Party               Eddie Cormier
# 13  2011  New Democratic Party              Maureen Larkin
# 14  2011  New Democratic Party               Roger Jeffery
# 15  2011  New Democratic Party   Egmont Riding Association
# 16  2011  New Democratic Party                   Betty Fay
# 17  2011  New Democratic Party                   Ron Kelly
# 18  2011  New Democratic Party          Jane Hughes Dunphy
# 19  2011  New Democratic Party         John Dean Constable
#
#                Community Province  Amount
# 0                Mermaid       PE   350.0
# 1                Mermaid       PE   400.0
# 2          Charlottetown       PE   500.0
# 3   Malpeque Association      NaN  5300.0
# 4           Murray River       PE   400.0
# 5                 Peakes       PE   400.0
# 6             Gaspereaux       PE  1500.0
# 7               Cornwall       PE  1540.0
# 8              Brookvale       PE  1700.0
# 9          Charlottetown       PE   265.0
# 10              Cornwall       PE   270.0
# 11              Cornwall       PE   270.0
# 12            Wellington       PE   290.0
# 13         Charlottetown       PE   290.0
# 14               O'Leary       PE   300.0
# 15            Summerside       PE   300.0
# 16           East Baltic      NaN   310.0
# 17         Charlottetown       PE   330.0
# 18              Cardigan       PE   370.0
# 19         Charlottetown       PE   390.0

# %%
# Save this cleaned data to a CSV.
df.to_csv('../resources/transformed_data/election_contributions_transformed.csv', index=False)
