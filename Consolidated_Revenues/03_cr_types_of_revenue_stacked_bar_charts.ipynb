# %% [markdown]
# ## PEI Consolidated Revenue Analysis
#
# Using the data from [OD0032 PEI Consolidated Revenues](https://data.princeedwardisland.ca/Government-and-Economy/OD0032-PEI-Consolidated-Revenues/9yq6-iu36) for the years 2011-2019 we aim to mimic the visualizations featured on the open data hub.

# %%
# %matplotlib inline
# Dependencies.
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Style.
from matplotlib import style
style.use('fivethirtyeight')

# %%
# Data.
df = pd.read_csv('../resources/OD0032_PEI_Consolidated_Revenues.csv')
df.head(10)
# Out:
#       Source of Revenue                    Type of Revenue Financial Year  \
# 0  Government of Canada  Government of Canada Equalization        2011/12
# 1  Government of Canada  Canada Health and Social Transfer        2011/12
# 2  Government of Canada       Government of Canada - Other        2011/12
# 3            Provincial                          Sales Tax        2011/12
# 4            Provincial                  Real Property Tax        2011/12
# 5            Provincial                Personal Income Tax        2011/12
# 6            Provincial               Corporate Income Tax        2011/12
# 7            Provincial                        Other Taxes        2011/12
# 8            Provincial               Licenses and Permits        2011/12
# 9            Provincial                  Fees and Services        2011/12
#
#        Value
# 0  329022000
# 1  165378000
# 2  136303000
# 3  214142000
# 4   97760000
# 5  285750000
# 6   42079000
# 7  116683000
# 8   24991000
# 9   55601000

# %%
# Get list of Types of Revenue, ordered by largest to smallest.
a_df = df.set_index(['Financial Year']).drop(columns=['Source of Revenue'])

sorted_list =  a_df.loc[a_df.index=='2011/12'][['Type of Revenue', 'Value']] \
                    .sort_values('Value', ascending=False)['Type of Revenue'].tolist()
sorted_list
# Out:
# ['Government of Canada Equalization',
#  'Personal Income Tax',
#  'Sales Tax',
#  'Canada Health and Social Transfer',
#  'Government of Canada - Other',
#  'Other Taxes',
#  'Real Property Tax',
#  'Fees and Services',
#  'Government Business Enterprises',
#  'Corporate Income Tax',
#  'Licenses and Permits',
#  'Other income',
#  'Sales',
#  'Investment Income',
#  'Sinking Fund Revenue']

# %%
# Create a grouped DataFrame.
revtype_df = df.groupby(['Financial Year', 'Type of Revenue'], axis=0).sum()
revtype_df
# Out:
#                                                       Value
# Financial Year Type of Revenue
# 2011/12        Canada Health and Social Transfer  165378000
#                Corporate Income Tax                42079000
#                Fees and Services                   55601000
#                Government Business Enterprises     46171000
#                Government of Canada - Other       136303000
# ...                                                     ...
# 2018/19        Personal Income Tax                388080000
#                Real Property Tax                  123087000
#                Sales                               32926000
#                Sales Tax                          311562000
#                Sinking Fund Revenue                10515000
#
# [120 rows x 1 columns]

# %%
# Create a DataFrame with the unstacked data for an area chart - (to 100%).
oneh_df = revtype_df.unstack().apply(lambda x: x*100/sum(x), axis=1)
# Drop the unneeded extra column level.
oneh_df.columns = oneh_df.columns.droplevel()
# Organize the columns so the highest value is first.
sorted_df = oneh_df[sorted_list]
sorted_df
# Out:
# Type of Revenue  Government of Canada Equalization  Personal Income Tax  \
# Financial Year
# 2011/12                                  20.730771            18.004321
# 2012/13                                  21.106459            18.809560
# 2013/14                                  20.066933            12.904545
# 2014/15                                  20.836081            19.098472
# 2015/16                                  20.526387            19.817627
# 2016/17                                  20.686658            19.043322
# 2017/18                                  19.629203            19.189139
# 2018/19                                  20.146958            18.669441
#
# Type of Revenue  Sales Tax  Canada Health and Social Transfer  \
# Financial Year
# 2011/12          13.492498                          10.420013
# 2012/13          13.280209                          10.676553
# 2013/14          14.427504                          10.634233
# 2014/15          14.425394                          10.655140
# 2015/16          13.926936                          10.943949
# 2016/17          12.791407                          11.080204
# 2017/18          15.134032                          10.543472
# 2018/19          14.988375                          10.490785
#
# Type of Revenue  Government of Canada - Other  Other Taxes  Real Property Tax  \
# Financial Year
# 2011/12                              8.588077     7.351875           6.159589
# 2012/13                              5.497166     7.302775           6.340422
# 2013/14                              7.828291    12.202882           6.202662
# 2014/15                              7.236207     6.169448           6.339926
# 2015/16                              5.198933     6.287460           6.357284
# 2016/17                              6.109596     6.337252           6.239180
# 2017/18                              5.978469     5.904614           5.972533
# 2018/19                              6.561485     5.731059           5.921371
#
# Type of Revenue  Fees and Services  Government Business Enterprises  \
# Financial Year
# 2011/12                   3.503266                         2.909108
# 2012/13                   3.647036                         3.038842
# 2013/14                   3.565826                         2.734777
# 2014/15                   3.519807                         2.224316
# 2015/16                   3.546526                         3.208380
# 2016/17                   3.377342                         3.978620
# 2017/18                   3.286920                         3.589436
# 2018/19                   3.411859                         3.114460
#
# Type of Revenue  Corporate Income Tax  Licenses and Permits  Other income  \
# Financial Year
# 2011/12                      2.651282              1.574614      1.456854
# 2012/13                      3.267392              1.732035      1.940486
# 2013/14                      2.763681              1.826593      1.535253
# 2014/15                      3.037675              1.827249      1.320043
# 2015/16                      4.161239              1.822760      1.285262
# 2016/17                      4.350554              1.910885      1.301498
# 2017/18                      4.936644              1.864700      1.373370
# 2018/19                      4.502208              1.793051      2.002414
#
# Type of Revenue     Sales  Investment Income  Sinking Fund Revenue
# Financial Year
# 2011/12          1.438581           0.948385              0.770768
# 2012/13          1.748691           0.908879              0.703496
# 2013/14          2.025194           0.802027              0.479597
# 2014/15          2.039535           0.746245              0.524462
# 2015/16          1.684988           0.720757              0.511512
# 2016/17          1.678167           0.622231              0.493082
# 2017/18          1.547846           0.561110              0.488513
# 2018/19          1.583978           0.576709              0.505847

# %%
# Plot the area chart.
ax = sorted_df.plot.area(figsize=(10,8))

# Add a legend off to the side of the chart.
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1.0, 0.5))
